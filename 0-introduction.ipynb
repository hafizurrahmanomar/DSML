# %% [markdown]
# # 1️⃣ Python কী? (Introduction) & Python-এর বৈশিষ্ট্য (Characteristics / Features)

# %% [markdown]
# - Python এমন একটি ভাষা যেটা ইংরেজির মতো পড়তে সহজ(Easy to Learn & Easy to Read)
#
# - Python একটি High-level, Interpreted, General-purpose Programming Language
#
# - সহজ সিনট্যাক্স ও readability-এর জন্য বিখ্যাত
#
# - Cross-platform (Windows, Linux, macOS)
#
# - Large Standard Library
#
# - Open Source & Free
#
# - Object-Oriented & Functional Support

# %% [markdown]
# # 2️⃣ Python-এর ইতিহাস (History of Python)

# %% [markdown]
# - ১৯৮০-এর দশকে Guido van Rossum কাজ শুরু করেন
#
# - নামকরণ: Monty Python’s Flying Circus থেকে অনুপ্রাণিত
#
# - Guido van Rossum ১৯৯১ সালে Python তৈরি করেন
#
# - ১৯৯১ → Python 0.9.0
#
# - ২০০০ → Python 2.x
#
# - ২০০৮ → Python 3.x (বর্তমান স্ট্যান্ডার্ড)
#
# ## 👉 গুরুত্বপূর্ণ:
#
# - Python 2 এখন Deprecated
#
# - সব নতুন প্রজেক্টে Python 3 ব্যবহার করা হয়

# %% [markdown]
# # 3️⃣ Python কোথায় ব্যবহার হয়? (Use Case Worldwide)
# ### 🌍 বিশ্বব্যাপী ব্যবহার ক্ষেত্র

# %% [markdown]
# - Web Development (Django, Flask, DRF)
#
# - Mobile App Backend
#
# - Data Science
#
# - Machine Learning & AI
#
# - Cyber Security & Ethical Hacking
#
# - Automation & Scripting
#
# - Game Development
#
# - Desktop Application
#
# ### 🏢 ব্যবহারকারী কোম্পানি
#
# 1. Google
#
# 2. Facebook (Meta)
#
# 3. Netflix
#
# 3. Instagram
#
# 4. NASA
#
# 4. Spotify

# %% [markdown]
# # 4️⃣ Python কেন এত জনপ্রিয়?

# %% [markdown]
# - Beginner Friendly
#
# - Huge Community Support
#
# - Thousands of Libraries
#
# - Career Demand বেশি
#
# - Freelancing ও Remote Job সুবিধা

# %% [markdown]
# # 5️⃣ Program Development Environment কী?

# %% [markdown]
# - যেখানে Code লেখা হয়
#
# - যেখানে Code Run করা হয়
#
# - যেখানে Debug করা হয়
#
# **Python Development Environment-এর অংশ:**
#
# - Python Interpreter
#
# - Code Editor / IDE
#
# - Package Manager (pip / conda)

# %% [markdown]
# # 6️⃣ Python IDE / Editor লিস্ট

# %% [markdown]
# - Beginner → Jupyter Notebook => Jupyter Notebook মানে Live Python Classroom
#
# - All-round Developer → **VS Code** => VS Code হলো All-in-One Developer Tool
#
# - Professional Python → **PyCharm** => PyCharm মানে Python-এর জন্য Luxury IDE
#
# - Data Science → **Jupyter + Spyder** => Spyder হলো Scientist-দের Python Tool
#
# - Fast Editing → **Sublime Text** => Sublime Text মানে Speed

# %% [markdown]
# **কেন Jupyter Notebook ব্যবহার করবেন?**

# %% [markdown]
# - Browser-based Interactive Environment
#
# - ell-based Code Execution
#
# - Code + Output + Explanation একসাথে
#
# - Step-by-step Result দেখা যায়
#
# - Graph, Chart, Data Analysis সহজ

# %% [markdown]
# **Jupyter Notebook কোথায় Best?**

# %% [markdown]
# - Data Science
#
# - Machine Learning
